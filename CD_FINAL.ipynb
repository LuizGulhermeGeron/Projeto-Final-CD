# %% [markdown]
# #Trabalho Final
#
# #### Dataset:
# Sinistros de Trânsito Agrupados Por Ocorrência em 2007 (https://dados.gov.br/dados/conjuntos-dados/sinistros-de-transito-agrupados-por-ocorrencia), complementado pela estimativa da população de cada município em 2006 (https://www.ibge.gov.br/estatisticas/sociais/populacao/9103-estimativas-de-populacao.html?edicao=17283&t=downloads)

# %%
# !pip install unidecode
import pandas as pd
import numpy as np
import re
import unidecode
import duckdb
import matplotlib.pyplot as plt
import seaborn as sns
con = duckdb.connect()
import scipy.stats as st
import statsmodels.formula.api as smf
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.12/dist-packages (1.4.0)

# %%
df = pd.read_csv("datatran2007.csv",sep=";")
df_mun = pd.read_excel("POP2006-TCU.xls", header=[3, 4])[:-3]
df_mun.columns = ["SIGLA U.F.","COD U.F.", "COD MUNIC","MUNICÍPIOS","POP-2006"]
df_mun = df_mun[['SIGLA U.F.', 'MUNICÍPIOS', 'POP-2006']].copy()
df_mun.columns = ['uf', 'municipio', 'pop_2006']
# Out:
# /tmp/ipython-input-2596296201.py:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("datatran2007.csv",sep=";")

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127675 entries, 0 to 127674
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      127675 non-null  int64
#  1   data_inversa            127675 non-null  object
#  2   dia_semana              127675 non-null  object
#  3   horario                 127675 non-null  object
#  4   uf                      127675 non-null  object
#  5   br                      127675 non-null  object
#  6   km                      127675 non-null  object
#  7   municipio               127675 non-null  object
#  8   causa_acidente          127675 non-null  object
#  9   tipo_acidente           127675 non-null  object
#  10  classificacao_acidente  127675 non-null  object
#  11  fase_dia                127675 non-null  object
#  12  sentido_via             127675 non-null  object
#  13  condicao_metereologica  127675 non-null  object
#  14  tipo_pista              127675 non-null  object
#  15  tracado_via             127675 non-null  object
#  16  uso_solo                127675 non-null  object
#  17  ano                     127675 non-null  int64
#  18  pessoas                 127675 non-null  int64
#  19  mortos                  127675 non-null  int64
#  20  feridos_leves           127675 non-null  int64
#  21  feridos_graves          127675 non-null  int64
#  22  ilesos                  127675 non-null  int64
#  23  ignorados               127675 non-null  int64
#  24  feridos                 127675 non-null  int64
#  25  veiculos                127675 non-null  int64
# dtypes: int64(10), object(16)
# memory usage: 25.3+ MB
#         id data_inversa dia_semana   horario  uf   br     km  municipio  \
# 0       10   11/06/2007    Segunda  15:30:00  MG  381  623.2   OLIVEIRA
# 1       10   11/06/2007    Segunda  15:30:00  MG  381  623.2   OLIVEIRA
# 2  1032898   13/08/2007    Segunda  14:25:00  MG   40  585.5  ITABIRITO
# 3  1051130   12/02/2007    Segunda  02:10:00  MA  135   11.0   SAO LUIS
# 4  1066824   20/11/2007      Ter�a  05:30:00  CE  222   30.8    CAUCAIA
#
#                 causa_acidente            tipo_acidente  ... uso_solo   ano  \
# 0             Falta de aten��o          Colis�o frontal  ...    Rural  2007
# 1             Falta de aten��o          Colis�o frontal  ...    Rural  2007
# 2                       Outras           Sa�da de Pista  ...    Rural  2007
# 3             Animais na Pista  Atropelamento de animal  ...   Urbano  2007
# 4  Defeito mec�nico em ve�culo              Capotamento  ...    Rural  2007
#
#   pessoas mortos feridos_leves feridos_graves ilesos  ignorados  feridos  \
# 0       9      0             4              0      5          0        4
# 1       9      0             4              0      5          0        4
# 2       3      0             0              1      2          0        1
# 3       5      2             2              1      0          0        3
# 4       1      0             1              0      0          0        1
#
#    veiculos
# 0         6
# 1         6
# 2         1
# 3         1
# 4         1
#
# [5 rows x 26 columns]

# %%
df_mun.info()
df_mun.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5564 entries, 0 to 5563
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   uf         5564 non-null   object
#  1   municipio  5564 non-null   object
#  2   pop_2006   5564 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 130.5+ KB
#       uf       municipio   pop_2006
# 5559  GO      Vianópolis    12950.0
# 5560  GO  Vicentinópolis     6591.0
# 5561  GO        Vila Boa     3617.0
# 5562  GO   Vila Propício     5001.0
# 5563  DF        Brasília  2383784.0

# %% [markdown]
# ##2 Integração e Limpeza de Dados

# %%
df_raw = df.copy()
con.register("acidentes_raw", df_raw)

# %% [markdown]
# ###2.2 Limpeza de Dados (Obrigatório)

# %%
colunas_nao_numericas = [
"dia_semana",
"uf",
"br",
"causa_acidente",
"tipo_acidente",
"classificacao_acidente",
"fase_dia",
"sentido_via",
"condicao_metereologica",
"tipo_pista",
"tracado_via",
"uso_solo",
]

print("Valores unicos para as colunas não numéricas")
for coluna in colunas_nao_numericas:
    print(f"{coluna + " ("+ str(df[coluna].unique().size) +")":30}: {df[coluna].unique()}")
# Out:
# Valores unicos para as colunas não numéricas
# dia_semana (7)                : ['Segunda' 'Ter�a' 'Domingo' 'Quinta' 'Quarta' 'Sexta' 'S�bado']
# uf (28)                       : ['MG' 'MA' 'CE' 'PR' 'ES' 'GO' 'RJ' 'RS' 'SP' 'RN' 'SC' 'PA' 'PE' 'MT'
#  'BA' 'AL' 'TO' 'PI' 'MS' 'SE' 'RO' 'PB' 'AP' 'DF' 'AC' 'RR' 'AM' '(null)']
# br (196)                      : [381 40 135 222 230 277 101 251 70 116 158 280 470 60 386 376 316 10 232
#  262 282 473 242 290 153 50 343 104 267 163 365 304 364 392 20 287 235 367
#  472 402 293 226 324 210 354 414 476 495 424 373 471 110 393 319 601 463
#  452 406 407 285 493 174 605 317 428 408 459 468 418 146 465 469 450 423
#  401 488 356 405 410 259 361 480 427 460 156 330 425 377 432 80 308 419
#  412 429 485 '101' '40' '232' '135' '116' '280' '381' '316' '262' '50'
#  '364' '290' '277' '304' '163' '226' '70' '282' '153' '470' '285' '406'
#  '354' '324' '20' '476' '365' '488' '10' '222' '158' '60' '230' '393'
#  '392' '343' '386' '452' '287' '405' '235' '367' '376' '110' '408' '480'
#  '242' '450' '471' '174' '259' '601' '428' '427' '407' '414' '319' '424'
#  '104' '465' '267' '412' '468' '459' '401' '293' '251' '429' '317' '418'
#  '80' '330' '356' '472' '146' '423' '373' '361' '469' '433' '473' '605'
#  '210' '463' '410' '(null)' '460' '377' '493' '495' '156' '432' '308'
#  '419' '604' '402' '416' '404' '485' '425' 416]
# causa_acidente (11)           : ['Falta de aten��o' 'Outras' 'Animais na Pista'
#  'Defeito mec�nico em ve�culo' 'N�o guardar dist�ncia de seguran�a'
#  'Velocidade incompat�vel' 'Desobedi�ncia � sinaliza��o'
#  'Ingest�o de �lcool' 'Defeito na via' 'Dormindo' 'Ultrapassagem indevida']
# tipo_acidente (16)            : ['Colis�o frontal' 'Sa�da de Pista' 'Atropelamento de animal'
#  'Capotamento' 'Colis�o lateral' 'Atropelamento de pessoa'
#  'Colis�o traseira' 'Colis�o Transversal' 'Tombamento'
#  'Colis�o com objeto fixo' 'Danos Eventuais'
#  'Queda de motocicleta / bicicleta / ve�culo' 'Derramamento de Carga'
#  'Colis�o com bicicleta' 'Colis�o com objeto m�vel' 'Inc�ndio']
# classificacao_acidente (5)    : ['(null)' 'Com V�timas Feridas' 'Com V�timas Fatais' 'Sem V�timas'
#  'Ignorado']
# fase_dia (5)                  : ['Pleno dia' 'Plena noite' 'Amanhecer' 'Anoitecer' '(null)']
# sentido_via (2)               : ['Decrescente' 'Crescente']
# condicao_metereologica (10)   : ['Ceu Claro' 'Chuva' 'Nublado' 'Sol' 'Nevoeiro/neblina' 'Ignorada' 'Vento'
#  'Granizo' '(null)' 'Neve']
# tipo_pista (3)                : ['Dupla' 'Simples' 'M�ltipla']
# tracado_via (3)               : ['Reta' 'Curva' 'Cruzamento']
# uso_solo (2)                  : ['Rural' 'Urbano']

# %%
regex_data = r'^(0[1-9]|[12][0-9]|3[01])/(0[1-9]|1[0-2])/[0-9]{4}$'
regex_horario = r'^(?:[01]\d|2[0-3]):[0-5]\d:[0-5]\d$'


def verifica_formato(df,coluna,regex):
    return df[coluna].apply(lambda x: not bool(re.match(regex, x)))

print("Quantidade de entradas com data fora do padrão: " + str(verifica_formato(df,"data_inversa",regex_data).sum()))
print("Quantidade de entradas com horário fora do padrão: " + str(verifica_formato(df,"horario",regex_horario).sum()))

print("km tem dados (null)? " + str("(null)" in df["km"].unique()))
print("municipio tem dados (null)? " + str("(null)" in df["municipio"].unique()))
# Out:
# Quantidade de entradas com data fora do padrão: 0
# Quantidade de entradas com horário fora do padrão: 0
# km tem dados (null)? True
# municipio tem dados (null)? False

# %%
colunas_numericas = ['ano', 'pessoas', 'mortos', 'feridos_leves', 'feridos_graves', 'ilesos', 'ignorados', 'feridos', 'veiculos']

print("Quantidade de entradas com valor < 0 para as colunas numéricas")
for coluna in colunas_numericas:
    print(f"{coluna}: {df[coluna].apply(lambda x: x < 0).sum()}")
# Out:
# Quantidade de entradas com valor < 0 para as colunas numéricas
# ano: 0
# pessoas: 0
# mortos: 0
# feridos_leves: 0
# feridos_graves: 0
# ilesos: 0
# ignorados: 0
# feridos: 0
# veiculos: 0

# %% [markdown]
# ###Descrição dos problemas:
#
# Dataset de sinistros:
#
# 1. uf tem valor "(null)"
# 2. br tem valor "(null)"
# 3. br tem valores inteiros e de texto
# 4. classificacao_acidente tem valor "(null)"
# 5. causa_acidente tem valor "Outras"
# 6. fase_dia tem valor "(null)"
# 7. condicao_metereologica tem valor "(null)"
# 8. condicao_metereologica tem valor "Ignorada"
# 9. km é tipo object
# 10. km tem valor "(null)"
#
# Dataset de população estimada:
#
# 1. municípios possuem assentos e letras minúsculas

# %% [markdown]
# Dataset de sinistros:
#
# 1. (1) uf tem valor "(null)"
# 1. (2) br tem valor "(null)"
# 1. (4) classificacao_acidente tem valor "(null)"
# 1. (5) causa_acidente tem valor "Outras"
# 1. (6) fase_dia tem valor "(null)"
# 1. (7) condicao_metereologica tem valor "(null)"
# 1. (8) condicao_metereologica tem valor "Ignorada"
# 1. (10) km tem valor "(null)"

# %%
df = df.replace("(null)", np.nan)

df["causa_acidente"] = df["causa_acidente"].replace("Outras", np.nan)
df["condicao_metereologica"] = df["condicao_metereologica"].replace("Ignorada", np.nan)

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79811 entries, 3 to 127674
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      79811 non-null  int64
#  1   data_inversa            79811 non-null  object
#  2   dia_semana              79811 non-null  object
#  3   horario                 79811 non-null  object
#  4   uf                      79811 non-null  object
#  5   br                      79811 non-null  object
#  6   km                      79811 non-null  object
#  7   municipio               79811 non-null  object
#  8   causa_acidente          79811 non-null  object
#  9   tipo_acidente           79811 non-null  object
#  10  classificacao_acidente  79811 non-null  object
#  11  fase_dia                79811 non-null  object
#  12  sentido_via             79811 non-null  object
#  13  condicao_metereologica  79811 non-null  object
#  14  tipo_pista              79811 non-null  object
#  15  tracado_via             79811 non-null  object
#  16  uso_solo                79811 non-null  object
#  17  ano                     79811 non-null  int64
#  18  pessoas                 79811 non-null  int64
#  19  mortos                  79811 non-null  int64
#  20  feridos_leves           79811 non-null  int64
#  21  feridos_graves          79811 non-null  int64
#  22  ilesos                  79811 non-null  int64
#  23  ignorados               79811 non-null  int64
#  24  feridos                 79811 non-null  int64
#  25  veiculos                79811 non-null  int64
# dtypes: int64(10), object(16)
# memory usage: 16.4+ MB

# %% [markdown]
# Dataset de sinistros:
#
# 1. (3) br tem valores inteiros e de texto[
#
# 2. (9) km é tipo object

# %%
df["km"] = pd.to_numeric(df["km"], errors="coerce")
df["br"] = pd.to_numeric(df["br"], errors="coerce")

# %% [markdown]
# Dataset de população estimada:
#
# 1. (1) municípios possuem assentos e letras minúsculas

# %%
df_mun['municipio'] = (
    df_mun['municipio']
    .str.strip()
    .str.upper()
    .apply(unidecode.unidecode)
    .str.replace("'", "", regex=False)  # remove todas as aspas simples
)

df_mun.head()
# Out:
#    uf                municipio  pop_2006
# 0  RO     ALTA FLORESTA DOESTE   29005.0
# 1  RO  ALTO ALEGRE DOS PARECIS   15454.0
# 2  RO             ALTO PARAISO   16510.0
# 3  RO          ALVORADA DOESTE   19542.0
# 4  RO                ARIQUEMES   86924.0

# %%
for coluna in ["feridos_leves", "feridos_graves", "ilesos", "ignorados", "feridos", "veiculos"]:
    print(f"{coluna:20}: max: {str(df[coluna].unique().max())} mean: {df[coluna].mean()}")
# Out:
# feridos_leves       : max: 43 mean: 0.4439112403052211
# feridos_graves      : max: 34 mean: 0.17204395384094925
# ilesos              : max: 46 mean: 1.46408389820952
# ignorados           : max: 40 mean: 0.042763528836877125
# feridos             : max: 62 mean: 0.6159551941461703
# veiculos            : max: 12 mean: 1.7732392777937878

# %% [markdown]
# ###2.3 Consultas SQL e Visualizações para Diagnóstico de Qualidade
#
# Dados originais:

# %%
con.register("acidentes", df)

# %%
print("Contagem de valores problemáticos no dataset BRUTO")
con.execute("""
    SELECT
        SUM(CASE WHEN uf = '(null)' OR uf IS NULL THEN 1 ELSE 0 END)               AS n_uf_nulos,
        SUM(CASE WHEN br = '(null)' OR br IS NULL THEN 1 ELSE 0 END)               AS n_br_nulos,
        SUM(CASE WHEN classificacao_acidente = '(null)' THEN 1 ELSE 0 END)         AS n_classificacao_nulos,
        SUM(CASE WHEN causa_acidente = 'Outras' THEN 1 ELSE 0 END)                 AS n_causa_outras,
        SUM(CASE WHEN fase_dia = '(null)' OR fase_dia IS NULL THEN 1 ELSE 0 END)   AS n_fase_dia_nulos,
        SUM(CASE WHEN condicao_metereologica = '(null)' OR condicao_metereologica IS NULL THEN 1 ELSE 0 END) AS n_cond_met_nulos,
        SUM(CASE WHEN condicao_metereologica = 'Ignorada' THEN 1 ELSE 0 END)       AS n_cond_met_ignorada,
        SUM(CASE WHEN km = '(null)' OR km IS NULL THEN 1 ELSE 0 END)               AS n_km_nulos
    FROM acidentes_raw;
""").df()
# Out:
# Contagem de valores problemáticos no dataset BRUTO
#    n_uf_nulos  n_br_nulos  n_classificacao_nulos  n_causa_outras  \
# 0         5.0         5.0                    5.0         45968.0
#
#    n_fase_dia_nulos  n_cond_met_nulos  n_cond_met_ignorada  n_km_nulos
# 0              25.0              23.0               2967.0         5.0

# %%
con.execute("""
    SELECT
        uf,
        br,
        classificacao_acidente,
        causa_acidente,
        fase_dia,
        condicao_metereologica,
        condicao_metereologica,
        km
    FROM acidentes_raw
    WHERE
      uf = '(null)' OR uf IS NULL;
""").df()
# Out:
#        uf      br classificacao_acidente          causa_acidente     fase_dia  \
# 0  (null)  (null)     Com V�timas Fatais                  Outras    Pleno dia
# 1  (null)  (null)    Com V�timas Feridas  Ultrapassagem indevida    Pleno dia
# 2  (null)  (null)     Com V�timas Fatais      Ingest�o de �lcool  Plena noite
# 3  (null)  (null)    Com V�timas Feridas                  Outras    Pleno dia
# 4  (null)  (null)    Com V�timas Feridas        Animais na Pista  Plena noite
#
#   condicao_metereologica condicao_metereologica_1      km
# 0              Ceu Claro                Ceu Claro  (null)
# 1              Ceu Claro                Ceu Claro  (null)
# 2              Ceu Claro                Ceu Claro  (null)
# 3              Ceu Claro                Ceu Claro  (null)
# 4              Ceu Claro                Ceu Claro  (null)

# %%
con.execute("""
    SELECT
        uf,
        br,
        classificacao_acidente,
        causa_acidente,
        fase_dia,
        condicao_metereologica,
        condicao_metereologica,
        km
    FROM acidentes_raw
    WHERE
      classificacao_acidente = '(null)' OR classificacao_acidente IS NULL;
""").df()
# Out:
#    uf   br classificacao_acidente    causa_acidente     fase_dia  \
# 0  MG  381                 (null)  Falta de aten��o    Pleno dia
# 1  MG  381                 (null)  Falta de aten��o    Pleno dia
# 2  MA  135                 (null)            Outras    Anoitecer
# 3  ES  262                 (null)  Falta de aten��o    Pleno dia
# 4  DF   60                 (null)  Falta de aten��o  Plena noite
#
#   condicao_metereologica condicao_metereologica_1     km
# 0              Ceu Claro                Ceu Claro  623.2
# 1                  Chuva                    Chuva  623.2
# 2                  Chuva                    Chuva    2.7
# 3                    Sol                      Sol   75.7
# 4              Ceu Claro                Ceu Claro      3

# %%
con.execute("""
    SELECT
        uf,
        br,
        classificacao_acidente,
        causa_acidente,
        fase_dia,
        condicao_metereologica,
        condicao_metereologica,
        km
    FROM acidentes_raw
    WHERE
      fase_dia = '(null)' OR fase_dia IS NULL;
""").df()
# Out:
#     uf   br classificacao_acidente                      causa_acidente  \
# 0   MT  163            Sem V�timas                    Falta de aten��o
# 1   MT  174            Sem V�timas                            Dormindo
# 2   PE  101            Sem V�timas             Velocidade incompat�vel
# 3   SC  282            Sem V�timas             Velocidade incompat�vel
# 4   PE  408    Com V�timas Feridas             Velocidade incompat�vel
# 5   DF   40            Sem V�timas             Velocidade incompat�vel
# 6   SC  470            Sem V�timas                    Falta de aten��o
# 7   MG   40    Com V�timas Feridas                              Outras
# 8   PE  101            Sem V�timas                    Falta de aten��o
# 9   RS  116    Com V�timas Feridas                    Falta de aten��o
# 10  RS  116            Sem V�timas  N�o guardar dist�ncia de seguran�a
# 11  ES  101            Sem V�timas             Velocidade incompat�vel
# 12  PR  277    Com V�timas Feridas                  Ingest�o de �lcool
# 13  MG  356    Com V�timas Feridas                    Falta de aten��o
# 14  TO  153    Com V�timas Feridas              Ultrapassagem indevida
# 15  RS  285            Sem V�timas                    Falta de aten��o
# 16  CE  116            Sem V�timas  N�o guardar dist�ncia de seguran�a
# 17  GO  153    Com V�timas Feridas                    Falta de aten��o
# 18  RJ  101    Com V�timas Feridas                  Ingest�o de �lcool
# 19  PB  230    Com V�timas Feridas                    Falta de aten��o
# 20  SP  116            Sem V�timas                              Outras
# 21  SC  470    Com V�timas Feridas             Velocidade incompat�vel
# 22  BA  116            Sem V�timas                              Outras
# 23  BA  101    Com V�timas Feridas                              Outras
# 24  PA  163    Com V�timas Feridas                    Falta de aten��o
#
#    fase_dia condicao_metereologica condicao_metereologica_1     km
# 0    (null)       Nevoeiro/neblina         Nevoeiro/neblina  793.9
# 1    (null)              Ceu Claro                Ceu Claro   27.2
# 2    (null)                 (null)                   (null)   68.9
# 3    (null)                 (null)                   (null)    217
# 4    (null)                 (null)                   (null)   93.5
# 5    (null)                 (null)                   (null)    3.5
# 6    (null)                Nublado                  Nublado     60
# 7    (null)                 (null)                   (null)    477
# 8    (null)                 (null)                   (null)    186
# 9    (null)                 (null)                   (null)  242.6
# 10   (null)              Ceu Claro                Ceu Claro  261.8
# 11   (null)                 (null)                   (null)  268.6
# 12   (null)                Nublado                  Nublado   71.4
# 13   (null)                 (null)                   (null)  279.6
# 14   (null)                    Sol                      Sol  342.4
# 15   (null)                  Chuva                    Chuva  130.2
# 16   (null)              Ceu Claro                Ceu Claro    3.3
# 17   (null)              Ceu Claro                Ceu Claro  500.2
# 18   (null)                Nublado                  Nublado    453
# 19   (null)       Nevoeiro/neblina         Nevoeiro/neblina  168.3
# 20   (null)                  Chuva                    Chuva   15.2
# 21   (null)              Ceu Claro                Ceu Claro  141.0
# 22   (null)               Ignorada                 Ignorada  617.2
# 23   (null)                 (null)                   (null)  137.0
# 24   (null)              Ceu Claro                Ceu Claro  991.0

# %%
print("Tipagem e conversão do campo km no dataset BRUTO")
con.execute("""
    SELECT
        COUNT(*) AS total_linhas,
        SUM(CASE WHEN km = '(null)' OR km IS NULL THEN 1 ELSE 0 END)                                 AS km_nulos,
        SUM(CASE WHEN km IS NOT NULL AND km <> '(null)' AND TRY_CAST(km AS DOUBLE) IS NOT NULL THEN 1 ELSE 0 END) AS km_convertido_numero,
        SUM(CASE WHEN km IS NOT NULL AND km <> '(null)' AND TRY_CAST(km AS DOUBLE) IS NULL THEN 1 ELSE 0 END)     AS km_valor_inesperado
    FROM acidentes_raw;
""").df()
# Out:
# Tipagem e conversão do campo km no dataset BRUTO
#    total_linhas  km_nulos  km_convertido_numero  km_valor_inesperado
# 0        127675       5.0              127670.0                  0.0

# %%
# Bloco 7 – heatmaps de dados faltantes (antes x depois da limpeza)

colunas_qualidade = [
    "uf",
    "br",
    "classificacao_acidente",
    "causa_acidente",
    "fase_dia",
    "condicao_metereologica",
    "km",
]

# para o dataset BRUTO, tratamos "(null)" como faltante só para visualização
df_raw_na = df_raw.replace("(null)", np.nan).replace("Ignorada", np.nan).replace("Outras", np.nan)

amostra_raw = df_raw_na[colunas_qualidade].sample(500, random_state=42)
amostra_limpa = df[colunas_qualidade].sample(500, random_state=42)

plt.figure(figsize=(10, 4))
sns.heatmap(amostra_raw.isna(), cbar=False, yticklabels=False)
plt.title("Heatmap de dados faltantes – amostra (dataset BRUTO)")
plt.xlabel("Atributos")
plt.ylabel("Ocorrências (amostra)")
plt.tight_layout()
plt.show()

# %%
colunas_numericas_box = ["pessoas", "mortos", "feridos", "veiculos"]

plt.figure(figsize=(7, 5))
sns.boxplot(data=df_raw[colunas_numericas_box])
plt.title("Outliers – atributos de severidade (dataset BRUTO)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Observam-se diversas linhas com valores "(null)" em algumas colunas (UF, BR, classificação do acidente, fase do dia, condição meteorológica e km), além de muitas ocorrências em que condicao_metereologica está marcada como "Ignorada" e causa_acidente como "Outras" o que indica informação pouco útil para análise.
#
# O dataset bruto apresenta um número considerável de linhas em que km e br são "(null)" o que impedia que as colunas fossem convertidas para um tipo numérico.
#
# Os outliers não apresentam valores absurdos, sendo seu possível impacto no desempenho do futuro modelo questionável. Por isso eles foram mantidos.
#
# Dados tratados:

# %%
print("Contagem de valores problemáticos no dataset BRUTO")
con.execute("""
    SELECT
        SUM(CASE WHEN uf = '(null)' OR uf IS NULL THEN 1 ELSE 0 END)               AS n_uf_nulos,
        SUM(CASE WHEN br IS NULL THEN 1 ELSE 0 END)               AS n_br_nulos,
        SUM(CASE WHEN classificacao_acidente = '(null)' THEN 1 ELSE 0 END)         AS n_classificacao_nulos,
        SUM(CASE WHEN causa_acidente = 'Outras' THEN 1 ELSE 0 END)                 AS n_causa_outras,
        SUM(CASE WHEN fase_dia = '(null)' OR fase_dia IS NULL THEN 1 ELSE 0 END)   AS n_fase_dia_nulos,
        SUM(CASE WHEN condicao_metereologica = '(null)' OR condicao_metereologica IS NULL THEN 1 ELSE 0 END) AS n_cond_met_nulos,
        SUM(CASE WHEN condicao_metereologica = 'Ignorada' THEN 1 ELSE 0 END)       AS n_cond_met_ignorada,
        SUM(CASE WHEN km IS NULL THEN 1 ELSE 0 END)               AS n_km_nulos
    FROM acidentes;
""").df()
# Out:
# Contagem de valores problemáticos no dataset BRUTO
#    n_uf_nulos  n_br_nulos  n_classificacao_nulos  n_causa_outras  \
# 0         0.0         0.0                    0.0             0.0
#
#    n_fase_dia_nulos  n_cond_met_nulos  n_cond_met_ignorada  n_km_nulos
# 0               0.0               0.0                  0.0         0.0

# %%
plt.figure(figsize=(10, 4))
sns.heatmap(amostra_limpa.isna(), cbar=False, yticklabels=False)
plt.title("Heatmap de dados faltantes – amostra (dataset LIMPO)")
plt.xlabel("Atributos")
plt.ylabel("Ocorrências (amostra)")
plt.tight_layout()
plt.show()

# %% [markdown]
# Após a limpeza (substituição de "(null)", "Ignorada" e "Outras"  por NaN e remoção das linhas incompletas), as mesmas consultas mostram que essas contagens de valores problemáticos diminuem para zero. Isso evidencia que os registros usados nas etapas seguintes já não carregam campos vazios ou categorias “lixo” nessas variáveis. Com a remoção dos valores nulos, a totalidade dos valores de km e br passou a ser convertível para tipo numérico.
#
# ###2.1 Enriquecimento com Fontes Externas (Opcional, mas encorajado)

# %%
df = df.merge(
    df_mun,
    on=['uf', 'municipio'],
    how='left'
)

faltantes = df[df['pop_2006'].isna()]
print(f"Linhas sem população: {len(faltantes)}")
faltantes[['uf', 'municipio']].head(20)
# Out:
# Linhas sem população: 172
#       uf                municipio
# 241   BA  MUQUEM DO SAO FRANCISCO
# 376   SC                 PICARRAS
# 565   RO          ITAPU� DO OESTE
# 1385  SC                 PICARRAS
# 1759  RS              ENTRE IJUIS
# 2795  SC                 PICARRAS
# 3716  RS              ENTRE IJUIS
# 3789  BA  MUQUEM DO SAO FRANCISCO
# 3944  SC        SAO MIGUEL DOESTE
# 4048  SC        SAO MIGUEL DOESTE
# 4234  SC                 PICARRAS
# 4342  RN                     ASSU
# 4756  RS              ENTRE IJUIS
# 4799  RS              ENTRE IJUIS
# 4831  RO      VILA NOVA DO MAMORE
# 4985  BA  MUQUEM DO SAO FRANCISCO
# 5915  RS              ENTRE IJUIS
# 6735  SC                 PICARRAS
# 7920  SC        SAO MIGUEL DOESTE
# 8502  RS              ENTRE IJUIS

# %%
df["hora"] = df["horario"].map(lambda x: int(x.split(":")[0]))
df["mes"] = df["data_inversa"].map(lambda x: int(x.split("/")[1]))
df["fim_semana"] = df["dia_semana"].isin(["Sábado", "Domingo"])
df.head()
# Out:
#         id data_inversa dia_semana   horario  uf   br     km  \
# 0  1051130   12/02/2007    Segunda  02:10:00  MA  135   11.0
# 1  1066824   20/11/2007      Ter�a  05:30:00  CE  222   30.8
# 2  1333766   17/07/2007      Ter�a  14:00:00  GO   70  372.0
# 3   173714   01/01/2007    Segunda  00:03:00  RJ  116  305.5
# 4   173715   01/01/2007    Segunda  00:50:00  RJ  101  321.5
#
#                 municipio                      causa_acidente  \
# 0                SAO LUIS                    Animais na Pista
# 1                 CAUCAIA         Defeito mec�nico em ve�culo
# 2  MONTES CLAROS DE GOIAS                    Falta de aten��o
# 3                 RESENDE                    Animais na Pista
# 4                 NITEROI  N�o guardar dist�ncia de seguran�a
#
#              tipo_acidente  ... feridos_leves feridos_graves ilesos ignorados  \
# 0  Atropelamento de animal  ...             2              1      0         0
# 1              Capotamento  ...             1              0      0         0
# 2          Colis�o lateral  ...             0              1      1         0
# 3  Atropelamento de animal  ...             0              0      1         0
# 4         Colis�o traseira  ...             0              0      2         0
#
#   feridos veiculos  pop_2006  hora  mes  fim_semana
# 0       3        1  998385.0     2    2       False
# 1       1        1  313584.0     5   11       False
# 2       1        2    7652.0    14    7       False
# 3       0        1  119729.0     0    1       False
# 4       0        2  476669.0     0    1       False
#
# [5 rows x 30 columns]

# %% [markdown]
# ##3 Análise Exploratória e Consultas SQL
#
# ###3.2 Preparação dos Dados em Formato Tidy

# %%
df["data_inversa"] = pd.to_datetime(df["data_inversa"], format="%d/%m/%Y")

# %%
df["fim_semana"] = df["data_inversa"].dt.weekday
df["mes"] = df["data_inversa"].dt.month
df["dia"] = df["data_inversa"].dt.day

# %%
df.to_parquet("sinistros2007.parquet", index=False, compression="snappy")

# %% [markdown]
# ###3.3 Consultas SQL Analíticas (5+ obrigatórias)

# %%
df.info()
con.register("sinistros2007", df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79811 entries, 0 to 79810
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      79811 non-null  int64
#  1   data_inversa            79811 non-null  datetime64[ns]
#  2   dia_semana              79811 non-null  object
#  3   horario                 79811 non-null  object
#  4   uf                      79811 non-null  object
#  5   br                      79811 non-null  int64
#  6   km                      79811 non-null  float64
#  7   municipio               79811 non-null  object
#  8   causa_acidente          79811 non-null  object
#  9   tipo_acidente           79811 non-null  object
#  10  classificacao_acidente  79811 non-null  object
#  11  fase_dia                79811 non-null  object
#  12  sentido_via             79811 non-null  object
#  13  condicao_metereologica  79811 non-null  object
#  14  tipo_pista              79811 non-null  object
#  15  tracado_via             79811 non-null  object
#  16  uso_solo                79811 non-null  object
#  17  ano                     79811 non-null  int64
#  18  pessoas                 79811 non-null  int64
#  19  mortos                  79811 non-null  int64
#  20  feridos_leves           79811 non-null  int64
#  21  feridos_graves          79811 non-null  int64
#  22  ilesos                  79811 non-null  int64
#  23  ignorados               79811 non-null  int64
#  24  feridos                 79811 non-null  int64
#  25  veiculos                79811 non-null  int64
#  26  pop_2006                79639 non-null  float64
#  27  hora                    79811 non-null  int64
#  28  mes                     79811 non-null  int32
#  29  fim_semana              79811 non-null  int32
#  30  dia                     79811 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(3), int64(12), object(13)
# memory usage: 18.0+ MB

# %%
print("Tendências temporais: número diário de sinistros com média móvel")
df_trend = con.execute("""
WITH diarios AS (
    SELECT
        CAST(data_inversa AS DATE) AS dia,
        COUNT(*) AS total_sinistros
    FROM sinistros2007
    GROUP BY CAST(data_inversa AS DATE)
)
SELECT
    dia,
    total_sinistros,
    AVG(total_sinistros) OVER (
        ORDER BY dia
        ROWS BETWEEN 6 PRECEDING AND CURRENT ROW
    ) AS media_movel_7d
FROM diarios
ORDER BY dia;

""").df()

plt.figure(figsize=(14, 5))
plt.plot(df_trend["dia"], df_trend["total_sinistros"], label="Sinistros Diários")
plt.plot(df_trend["dia"], df_trend["media_movel_7d"], label="Média Móvel 7 dias")
plt.xlabel("Data")
plt.ylabel("Quantidade de Sinistros")
plt.title("Tendência Temporal de Sinistros em 2007")
plt.legend()
plt.tight_layout()
plt.show()
df_trend
# Out:
# Tendências temporais: número diário de sinistros com média móvel
#            dia  total_sinistros  media_movel_7d
# 0   2007-01-01              275      275.000000
# 1   2007-01-02              297      286.000000
# 2   2007-01-03              197      256.333333
# 3   2007-01-04              194      240.750000
# 4   2007-01-05              230      238.600000
# ..         ...              ...             ...
# 360 2007-12-27              230      304.857143
# 361 2007-12-28              293      286.285714
# 362 2007-12-29              314      266.428571
# 363 2007-12-30              228      256.714286
# 364 2007-12-31              132      245.571429
#
# [365 rows x 3 columns]

# %%
print("Comparação entre grupos: taxa de mortos por tipo de acidente")
df_tipo = con.execute("""
SELECT
    tipo_acidente,
    COUNT(*) AS ocorrencias,
    SUM(mortos) AS total_mortos,
    ROUND(SUM(mortos)::numeric / COUNT(*), 3) AS media_mortos_por_acidente
FROM sinistros2007
GROUP BY tipo_acidente
ORDER BY media_mortos_por_acidente DESC;

""").df()

plt.figure(figsize=(12, 6))
plt.bar(df_tipo["tipo_acidente"], df_tipo["media_mortos_por_acidente"])
plt.xticks(rotation=90)
plt.ylabel("Média de Mortes por Acidente")
plt.xlabel("Tipo de Acidente")
plt.title("Média de Mortes por Tipo de Acidente – Sinistros 2007")
plt.tight_layout()
plt.show()
df_tipo
# Out:
# Comparação entre grupos: taxa de mortos por tipo de acidente
#                                  tipo_acidente  ocorrencias  total_mortos  \
# 0                              Colis�o frontal         2822        1002.0
# 1                      Atropelamento de pessoa         1808         402.0
# 2                        Colis�o com bicicleta         1618         242.0
# 3                                  Capotamento         3340         221.0
# 4                          Colis�o Transversal         9303         338.0
# 5                      Colis�o com objeto fixo         3964         116.0
# 6                                   Tombamento         3211          92.0
# 7                               Sa�da de Pista         9577         264.0
# 8   Queda de motocicleta / bicicleta / ve�culo         1382          38.0
# 9                              Colis�o lateral        13785         309.0
# 10                     Atropelamento de animal         3113          62.0
# 11                    Colis�o com objeto m�vel          781          14.0
# 12                                    Inc�ndio          265           4.0
# 13                             Danos Eventuais          403           6.0
# 14                            Colis�o traseira        24209         270.0
# 15                       Derramamento de Carga          230           0.0
#
#     media_mortos_por_acidente
# 0                       0.355
# 1                       0.222
# 2                       0.150
# 3                       0.066
# 4                       0.036
# 5                       0.029
# 6                       0.029
# 7                       0.028
# 8                       0.027
# 9                       0.022
# 10                      0.020
# 11                      0.018
# 12                      0.015
# 13                      0.015
# 14                      0.011
# 15                      0.000

# %%
print("Análise de concentração (Pareto): 80% dos mortos vêm de quantas causas?")
con.execute("""

WITH base AS (
    SELECT
        causa_acidente,
        SUM(mortos) AS mortos
    FROM sinistros2007
    GROUP BY causa_acidente
),
ordenado AS (
    SELECT
        *,
        SUM(mortos) OVER (ORDER BY mortos DESC) AS acumulado,
        SUM(mortos) OVER () AS total
    FROM base
)
SELECT
    causa_acidente,
    mortos,
    acumulado,
    ROUND(acumulado / total, 3) AS perc_acumulado
FROM ordenado
ORDER BY mortos DESC;

""").df()
# Out:
# Análise de concentração (Pareto): 80% dos mortos vêm de quantas causas?
#                        causa_acidente  mortos  acumulado  perc_acumulado
# 0                    Falta de aten��o  1436.0     1436.0           0.425
# 1             Velocidade incompat�vel   513.0     1949.0           0.577
# 2              Ultrapassagem indevida   494.0     2443.0           0.723
# 3                            Dormindo   214.0     2657.0           0.786
# 4         Desobedi�ncia � sinaliza��o   209.0     2866.0           0.848
# 5                  Ingest�o de �lcool   172.0     3038.0           0.899
# 6         Defeito mec�nico em ve�culo   117.0     3155.0           0.933
# 7                    Animais na Pista    96.0     3251.0           0.962
# 8  N�o guardar dist�ncia de seguran�a    65.0     3316.0           0.981
# 9                      Defeito na via    64.0     3380.0           1.000

# %%
print("Detecção de anomalias: dias com número atípico de acidentes (Z-Score)")
con.execute("""

WITH diarios AS (
    SELECT
        data_inversa::date AS dia,
        COUNT(*) AS total_sinistros
    FROM sinistros2007
    GROUP BY dia, data_inversa
),
stats AS (
    SELECT
        AVG(total_sinistros) AS media,
        STDDEV_POP(total_sinistros) AS sd
    FROM diarios
)
SELECT
    d.*,
    (d.total_sinistros - s.media) / s.sd AS z_score
FROM diarios d CROSS JOIN stats s
WHERE ABS((d.total_sinistros - s.media) / s.sd) > 2.5
ORDER BY z_score DESC;

""").df()
# Out:
# Detecção de anomalias: dias com número atípico de acidentes (Z-Score)
#          dia  total_sinistros   z_score
# 0 2007-12-22              453  5.442866
# 1 2007-04-08              423  4.746075
# 2 2007-12-21              423  4.746075
# 3 2007-02-17              375  3.631208
# 4 2007-02-16              340  2.818284
# 5 2007-09-09              328  2.539567

# %%
print("Correlações e dependências: relação entre número de veículos e gravidade")
con.execute("""

SELECT
    veiculos,
    AVG(mortos) AS media_mortos,
    AVG(feridos) AS media_feridos,
    AVG(feridos_graves) AS media_graves
FROM sinistros2007
GROUP BY veiculos
HAVING veiculos <= 15
ORDER BY veiculos;

""").df()
# Out:
# Correlações e dependências: relação entre número de veículos e gravidade
#     veiculos  media_mortos  media_feridos  media_graves
# 0          1      0.042032       0.705667      0.184799
# 1          2      0.039514       0.558791      0.162457
# 2          3      0.061627       0.599330      0.174642
# 3          4      0.056502       0.713004      0.178475
# 4          5      0.036496       0.810219      0.233577
# 5          6      0.039474       0.671053      0.276316
# 6          7      0.133333       1.900000      0.566667
# 7          8      0.142857       1.285714      0.428571
# 8          9      0.000000       8.000000      0.000000
# 9         10      0.000000       5.000000      1.000000
# 10        11      4.000000       4.000000      1.000000
# 11        12     14.000000      62.000000     34.000000

# %% [markdown]
# ###3.4 Análise Exploratória e Teste de Hipóteses
#
# ####Análise univariada

# %%
cols_num = ["mortos", "feridos", "feridos_graves", "veiculos", "pessoas", "hora", "km"]

df[cols_num].hist(figsize=(14, 10), bins=30)
plt.suptitle("Distribuições Univariadas", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(df["mortos"])
plt.title("Outliers em Mortes")
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(df["feridos"])
plt.title("Outliers em Feridos")
plt.show()

# %% [markdown]
# ####Análise bivariada

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df[cols_num].corr(), annot=True, cmap="coolwarm")
plt.title("Matriz de Correlação")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df, x="fase_dia", y="mortos")
plt.title("Mortes por Fase do Dia")
plt.show()

# %%
df["grave"] = (df["mortos"] > 0).astype(int)

plt.figure(figsize=(12,6))
sns.barplot(data=df, x="condicao_metereologica", y="grave", estimator=sum)
plt.xticks(rotation=45)
plt.title("Acidentes Graves por Condição Meteorológica")
plt.show()

# %% [markdown]
# ####Análise multivariada

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(df.corr(numeric_only=True), cmap="viridis")
plt.title("Correlação Completa")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

features = ["veiculos", "mortos", "feridos", "hora", "pop_2006"]
df_clean = df[features].dropna()

scaler = StandardScaler()
X = scaler.fit_transform(df_clean)

pca = PCA(n_components=2)
components = pca.fit_transform(X)

plt.figure(figsize=(8,6))
plt.scatter(components[:,0], components[:,1], alpha=0.3)
plt.title("PCA – Acidentes 2007")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %% [markdown]
# ####Teste de hipóteses

# %% [markdown]
# H1: Fatores ambientais e temporais influenciam a gravidade do sinistro

# %%
groups = [g["mortos"].values for _, g in df.groupby("fase_dia")]
f_stat, p_value = st.f_oneway(*groups)
print("ANOVA mortos ~ fase_dia:", p_value)
# Out:
# ANOVA mortos ~ fase_dia: 3.8233613031366624e-47

# %%
tabela = pd.crosstab(df["condicao_metereologica"], df["grave"])
chi2, p, dof, exp = st.chi2_contingency(tabela)

print("Qui-quadrado clima × gravidade:", p)
# Out:
# Qui-quadrado clima × gravidade: 3.5852705469560646e-17

# %% [markdown]
# H2: O número de veículos envolvidos e o tipo de pista são preditores significativos da
# gravidade

# %%
df["grave"] = (df["mortos"] > 0).astype(int)
modelo = smf.logit("grave ~ veiculos + C(tipo_pista)", data=df).fit()
print(modelo.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.144459
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  grave   No. Observations:                79811
# Model:                          Logit   Df Residuals:                    79807
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 25 Nov 2025   Pseudo R-squ.:                 0.01625
# Time:                        22:10:01   Log-Likelihood:                -11529.
# converged:                       True   LL-Null:                       -11720.
# Covariance Type:            nonrobust   LLR p-value:                 2.871e-82
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -3.9599      0.068    -58.225      0.000      -4.093      -3.827
# C(tipo_pista)[T.M�ltipla]    -0.3588      0.114     -3.136      0.002      -0.583      -0.135
# C(tipo_pista)[T.Simples]      0.7741      0.048     16.069      0.000       0.680       0.869
# veiculos                      0.0574      0.029      2.005      0.045       0.001       0.114
# =============================================================================================
